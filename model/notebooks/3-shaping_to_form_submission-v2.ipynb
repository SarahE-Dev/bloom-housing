# %% [markdown]
# # Form Submission to Features from Dataset
#
# **IMPORTANT**
#
# When dealing with the AHS 2023 National PUF v1.1 CSV (Not the flat file) - **PERSONID** adds 3 digits to the CONTROL column value to differentiate between household members
#
# LINK
# (https://www.census.gov/data-tools/demo/codebook/ahs/ahsdict.html?s_keyword=PERSONID&s_year=2023%20National,2023%20Metro&s_topic=&s_availability=PUF)
#
# **CONTROL** is used to map rows across the 4 CSVs (Person, Household, Mortgage, Project) - should think about adding columns we'll be using to each row in Persons CSV to map individual people to overall household features we may include
#
# ---
#
# ## Date of Birth
#
# Form question as Date so must be extracted from it
#
# ### AGE
#
# Age of respondent
#
# LINK
# (https://www.census.gov/data-tools/demo/codebook/ahs/ahsdict.html?s_keyword=&s_year=2023%20National,2023%20Metro&s_topic=&s_availability=PUF&s_variablelist=AGE)
#
# **Table Name - PERSON**
#
# User Notes
#
# AGE may be determined from either the birthdate (if provided) or the respondent's best estimate of age.
#
# #### **Response Codes**
#
#     0 to 84: 0 to 84 years old
#     85: 85 years or older
#
# ### HHAGE
#
# Age of householder
#
# LINK
# (https://www.census.gov/data-tools/demo/codebook/ahs/ahsdict.html?s_keyword=&s_year=2023%20National,2023%20Metro&s_topic=&s_availability=PUF&s_variablelist=HHAGE)
#
# **Table Name - HOUSEHOLD**
#
# User Notes
#
# AGE may be determined from either the birthdate (if provided) or the respondent's best estimate of age.
#
# #### **Response Codes**
#
#     0 to 84: 0 to 84 years old
#     85: 85 years or older
#     N or -6: Not applicable
#
# ---
#
# ## Phone/Additional Phone
#
# Form question asks what type of phone they have + any additional phones
#
# ### CELLPHONE
#
# Number of adults with cell phones for personal use
#
# LINK
# (https://www.census.gov/data-tools/demo/codebook/ahs/ahsdict.html?s_keyword=&s_year=2023%20National,2023%20Metro&s_topic=&s_availability=PUF&s_variablelist=CELLPHONE)
#
# **Table Name - HOUSEHOLD**
#
# Question Text:
# How many adults age 18 and over in this household have a cell phone for personal use?
#
# #### **Response Codes**
#
#     0 to 99: Number of cellphones in the household
#     M or -9: Not reported
#     N or -6: Not applicable
#
# ### LANDLINE
#
# Flag indicating landline telephone in home
#
# LINK
# (https://www.census.gov/data-tools/demo/codebook/ahs/ahsdict.html?s_keyword=&s_year=2023%20National,2023%20Metro&s_topic=&s_availability=PUF&s_variablelist=LANDLINE)
#
# **Table Name - HOUSEHOLD**
#
# Question Text:
# Is there a landline telephone in this house? Do not count cellular phones, or any phone line that is used only for a computer or fax machine.
#
# #### **Response Codes**
#
#     1: Yes
#     2: No
#     M or -9: Not reported
#     N or -6: Not applicable
#
# ---
#
# ## Alternate Contact
#
# Form question has options of Family Member, Friend, or Not having one (we want to take note of these specifically)
# and if 'Do they have the same address as you?" question is answered yes or no
#
# May or may not use this -- open to feedback on it
#
# ---
#
# ## Disability
#
# Form question asks if they or anyone in their household has a disability (Mobility, Hearing, Vision)
#
# NOTE: Variables to use to get specific disability information are: Household based HHHEAR/HHSEE/HHWALK and respondent based PHEAR/PSEE/PWALK
#
# ### DISHH
#
# Flag indicating disabled person household
#
# LINK
# (https://www.census.gov/data-tools/demo/codebook/ahs/ahsdict.html?s_keyword=&s_year=2023%20National,2023%20Metro&s_topic=&s_availability=PUF&s_variablelist=DISHH)
#
# **Table Name - HOUSEHOLD**
#
# User Notes
#
# The DISHH variable is a recode that uses all of the household level disability variables.
# It has values of '1' and '2' for houses that have a person with a disability or don't have a person with a disability respectively.
# The value 'M' is used to represent cases that had no positive disability responses and at least one "don't know" and/or refusal response.
#
# #### **Response Codes**
#
#     1: At least 1 disabled person in unit
#     2: No disabled persons in unit
#     M or -9: Not reported
#     N or -6: Not applicable
#
# ---
#
# ## Full time student or 18 yrs old - REPLACED
#
# ### HHADLTKIDS
#
# Number of the householder's unmarried children age 18 and over, living in this unit
#
# LINK
# (https://www.census.gov/data-tools/demo/codebook/ahs/ahsdict.html?s_keyword=&s_year=2023%20National,2023%20Metro&s_topic=&s_availability=PUF&s_variablelist=HHADLTKIDS)
#
# **Table Name - HOUSEHOLD**
#
# #### **Response Codes**
#
#     0 to 15: 0 to 15 children
#     N or -6: Not applicable
#
# ## Replacement of above
#
# ### NUMPEOPLE
#
# Number of persons living in this unit
#
# LINK
# (https://www.census.gov/data-tools/demo/codebook/ahs/ahsdict.html?s_keyword=NUMPEOPLE)
#
# **Table Name - HOUSEHOLD**
#
# NOTE: The addition of this proceeds being told to take the form question of:
# 'Next we would like to know about the others who will live with you in the unit.'
# and ot consider it as the applicants current living situation.
#
# #### **Response Codes**
#
#     1 to 29: 1 to 29 people
#     30: 30 or more people
#     N or -6: Not applicable
#
# ---
#
# ## Veteran Status
#
# Form question asks if anyone in the household is a veteran or active duty
#
# ### MILHH
#
# Type of military househould
#
# LINK
# (https://www.census.gov/data-tools/demo/codebook/ahs/ahsdict.html?s_keyword=MILHH&s_year=2023%20National,2023%20Metro&s_topic=&s_availability=PUF)
#
# **Table Name - HOUSEHOLD**
#
# NOTE: The below codes will be combined into a binary value of
#
#     0: Not a military household
#     1: Military household
#
# #### **Response Codes**
#
#     1: 1 person, active duty
#     2: 1 person, veteran
#     3: 2 or more persons, active duty, no veterans
#     4: 2 or more veterans
#     5: 2 or more, mix of active duty and veterans
#     6: No persons served in the military
#     N or -6: Not applicable
#
# ### MIL
#
# Military status of person
#
# LINK
# (https://www.census.gov/data-tools/demo/codebook/ahs/ahsdict.html?s_keyword=&s_year=2023%20National,2023%20Metro&s_topic=&s_availability=PUF&s_variablelist=MIL)
#
# **Table Name - PERSON**
#
# User Notes
#
# MIL is determined using AFEVER (Did you ever serve on active duty in the U. S. Armed Forces?) and AFNOW (Are you now in the Armed Forces?).
#
# #### **Response Codes**
#
#     1: Now on active duty
#     2: Served on active duty in the past
#     3: Never served in military
#     M or -9: Not reported
#     N or -6: Not applicable
#
# ---
#
# ## Government Assistance
#
# Form asks if applicant receives: Housing Vouchers, Non-taxable income (SSI/SSDI/Child Support/WorkersComp/etc), or Rental Subsidies (VASH/HSA/HOPWA/Catholic Charities/AIDS Foundation/etc)
#
# ### FS
#
# Flag indicating food stamp or supplemental nutrition assistance program recipiency (past 12 months)
#
# LINK
# (https://www.census.gov/data-tools/demo/codebook/ahs/ahsdict.html?s_keyword=FS&s_year=2023%20National,2023%20Metro&s_topic=Income%20%3E%20Person%20Income,Income%20%3E%20Total%20Household%20Income&s_availability=PUF)
#
# **Table Name - HOUSEHOLD**
#
# Question Text
# In the 12 months prior to the date of the interview, did you receive benefits from the Food Stamp Benefits Program or SNAP (the Supplemental Nutrition Assistance Program)?
#
# #### **Response Codes**
#
#     1: Yes
#     2: No
#     M or -9: Not reported
#     N or -6: Not applicable
#
# ### PAP
#
# Person's public assistance income (past 12 months)
#
# LINK
# (https://www.census.gov/data-tools/demo/codebook/ahs/ahsdict.html?s_keyword=PAP&s_year=2023%20National,2023%20Metro&s_topic=Income%20%3E%20Person%20Income,Income%20%3E%20Total%20Household%20Income&s_availability=PUF)
#
# **Table Name - PERSON**
#
# User Notes
#
# Respondents were first asked QWELF (In the 12 months prior to the date of the interview, did you receive any public assistance, such as Temporary Assistance for Needy Families (TANF), or public welfare cash assistance from the state or local welfare office?), and if they replied yes, were then asked WELFQ (What was the amount?).
#
# #### **Response Codes**
#
#     0: Does not receive public assistance income
#     1 to 99997: $1 to $99,997
#     99998: $99,998 or more
#     N or -6: Not applicable
#
# ### HUDSUB
#
# Subsidized renter status and eligibility
#
# LINK
# (https://www.census.gov/data-tools/demo/codebook/ahs/ahsdict.html?s_keyword=HUDSUB)
#
# **Table Name - HOUSEHOLD**
#
# User Notes
#
# More information on the HUD-assisted renter oversample can be found at https://www.census.gov/programs-surveys/ahs/tech-documentation/help-guides/2015-later/renter_oversample.html. Also see "HUD-assisted status" in the Subject Definitions found at https://www.census.gov/programs-surveys/ahs/tech-documentation/def-errors-changes.html.
#
# #### **Response Codes**
#
#     1: HUD assisted: public housing and privately owned multifamily
#     2: HUD assisted: Housing Choice Voucher Program
#     3: All other renter occupied units
#     N or -6: Not applicable
#
# ### RENTCNTRL
#
# Flag indicating rent is limited by rent control or stabilization
#
# LINK
# (https://www.census.gov/data-tools/demo/codebook/ahs/ahsdict.html?s_keyword=RENTCNTRL&s_availability=PUF&s_year=2023%20National,2023%20Metro)
#
# **Table Name - HOUSEHOLD**
#
# User Notes
#
# RENTCNTRL is determined by either RCNTRL1 or RCNTRL2.
#
# #### **Response Codes**
#
#     1: Yes
#     2: No
#     M or -9: Not reported
#     N or -6: Not applicable
#
# ### RENTSUB
#
# Type of rental subsidy or reduction (based on respondent report)
#
# LINK
# (https://www.census.gov/data-tools/demo/codebook/ahs/ahsdict.html?s_keyword=RENTSUB&s_year=2023%20National,2023%20Metro&s_availability=PUF)
#
# **Table Name - HOUSEHOLD**
#
# #### **Response Codes**
#
#     1: Public housing
#     2: Portable voucher
#     3: Non-portable voucher
#     4: Other government subsidy
#     5: Rent reduction requiring annual recertification not reported elsewhere
#     6: Rent reduction because household member works for owner
#     7: Rent reduction because household member related to owner
#     8: No rental subsidy or reduction
#     M or -9: Not reported
#     N or -6: Not applicable
#
# ---
#
# ## Income
#
# Form asks to add up total gross household income before taxes and gives option of per month or year - turn this into total yearly income if 'per month' option selected
#
# ### HINCP
#
# Household income (past 12 months)
#
# LINK
# (https://www.census.gov/data-tools/demo/codebook/ahs/ahsdict.html?s_keyword=HINCP&s_year=2023%20National,2023%20Metro&s_topic=Income%20%3E%20Person%20Income,Income%20%3E%20Total%20Household%20Income&s_availability=PUF)
#
# **Table Name - Household**
#
# User Notes
#
# HINCP is the sum of all types of income for all household members age 16 and over.
#
# #### **Response Codes**
#
#     -99999999 to 99999998: -$99,999,999 to $99,999,998
#     99999999: $99,999,999 or more
#     N or -6: Not applicable
#
# ---
#
# # Finding 'At Risk' profiles
#
# We can use the features below to consider different possible ways someone may be at risk. This will help to capture different ranges of risk without needing to try and quantify it (at least for now). This will then use the features included from the form submission to discover the relationships in the data that we will use to return the probability of an applicant falling into an 'at risk' classification.
#
# ### PERPOVLVL
#
# Household income as percent of poverty threshold (rounded)
#
# **Table Name - HOUSEHOLD**
#
# Equal to or Less Than 100 = at risk
#
# Response Codes
#
#     1: Household income less than or equal to 0
#     2 to 500: 2 to 500 percent
#     501: 501 percent or more
#     N or -6: Not applicable
#
# ### HIHALF
#
# Flag indicating housing payment more than half of household's monthly income
#
# **Table Name - HOUSEHOLD**
#
# Equal to 1 = at risk
#
# Response Codes
#
#     1: Yes
#     2: No
#     M or -9: Not reported
#     N or -6: Not applicable
#
# ### HIBEHINDFRQ
#
# Number of months missed housing payments in last 12 months
#
# **Table Name - HOUSEHOLD**
#
# Equal to 2, 3, 4 = at risk
#
# Response Codes
#
#     1: Yes, 1 or 2 months
#     2: Yes, some months but not every month
#     3: Yes, almost every month
#     4: Yes, every month
#     5: Yes, number of months not reported
#     6: No payments behind
#     M or -9: Not reported
#     N or -6: Not applicable
#
# ### HIMORTFORC
#
# Flag indicating received foreclosure notice in last 12 months
#
# **Table Name - HOUSEHOLD**
#
# Equal to 1 = at risk
#
# Response Codes
#
#     1: Yes
#     2: No
#     M or -9: Not reported
#     N or -6: Not applicable
#
# ### HIEVICNOTE
#
# Flag indicating received an eviction notice in last 12 months
#
# **Table Name - HOUSEHOLD**
#
# Equal to 1 = at risk
#
# Response Codes
#
#     1: Yes
#     2: No
#     M or -9: Not reported
#     N or -6: Not applicable
#
# ### HINFORC
#
# Flag indicating mortgage currently in foreclosure
#
# **Table Name - HOUSEHOLD**
#
# Equal to 1 = at risk
#
# Response Codes
#
#     1: Yes
#     2: No
#     M or -9: Not reported
#     N or -6: Not applicable
#
# The features above were chosen because they encapsulate the entire household. There are other questions in the 'Housing Insecurity' topic that ask about how many members in the house may have experienced something, which you can not apply to every respondent in the household that is included in the `person.csv`.
#
# We should be coming up with more questions informed from the dataset to determine who can be considered at risk without necessarily quantifying how at risk they are. We will then use Machine Learning to see the common features of those who end up in an 'at risk' position
#
# HINFORC added 5/4 to check for more 'at risk' profiles. Another addition to consider is HINOWHERE in conjunction with the number of people being equal to the number of NUMPEOPLE & being low-income to determine some level of risk without quantifying it.

# %% [markdown]
# ---

# %% [markdown]
# # Household CSV Cleaning and Feature Engineering
#
# ### Features being targeted
#
# As mentioned above, the features to work with in the `household.csv` dataset are as follows:
#
# (**LANDLINE** encompasses the whole household, but **CELLPHONE** is specific to occupants of the household. Considering leaving this off for now because of that)
#
# _CELLPHONE_
#
# _LANDLINE_
#
# **Indicates if someone is disabled in the household**
#
#     DISHH
#     1: At least 1 disabled person in unit
#
# **Number of unmarried children 18+** -- replaced
#
#     HHADLTKIDS
#
# **Who you will live with in unit** -- replacement of above
#
#     NUMPEOPLE
#
# **Military household type**
#
# Used bc of how form question is asked
#
#     MILHH
#     1: 1 person, active duty
#     2: 1 person, veteran
#     3: 2 or more persons, active duty, no veterans
#     4: 2 or more veterans
#     5: 2 or more, mix of active duty and veterans
#     6: No persons served in the military
#     N or -6: Not applicable
#
# **Food Stamp or SNAP assistance (past 12 mo)**
#
# Use in conjunction with _PAP_ and _HUDSUB_ to combine into whether someone receives public assistance or not
#
#     FS
#     1: Yes
#
# **Subsidized renter status and eligibility**
#
#     HUDSUB
#     1: HUD assisted: public housing and privately owned multifamily
#     2: HUD assisted: Housing Choice Voucher Program
#
# ---
#
# **Household Income (past 12mo)**
#
#     HINCP
#
# ---
#
# ### Features being used to determine at risk profiles:
#
# **Income as percentage of Poverty Threshold**
#
#     PERPOVLVL <= 100
#
# **Housing Payment more than half of household's monthly income**
#
#     HIHALF == 1
#     1: Yes
#
# **Number of months housing payments missed**
#
#     HIBEHINDFRQ == 2, 3, 4
#     2: Some months but not every
#     3: Almost every month
#     4: Every month
#
# **Received foreclosure notice in last 12mo**
#
#     HIMORTFORC == 1
#     1: Yes
#
# **Received eviction notice in last 12 mo**
#
#     HIEVICNOTE == 1
#     1: Yes
#
# **Flag indicating mortgage currently in foreclosure**
#
#     HINFORC == 1
#     1: Yes

# %%
import pandas as pd


df = pd.read_csv(
    "../data/household.csv",
    usecols=[
        "CONTROL",
        "HINCP",
        "DISHH",
        "FS",
        "HUDSUB",
        "RENTSUB",
        "RENTCNTRL",
        "NUMPEOPLE",
        "PERPOVLVL",
        "HIHALF",
        "HIBEHINDFRQ",
        "HIMORTFORC",
        "HIEVICNOTE",
        "HINFORC",
        "MILHH",
    ],
)

print(df.head(20))

print(f"\n\n{len(df)} Households loaded")
# Out:
#        CONTROL  PERPOVLVL HINFORC HIHALF RENTCNTRL RENTSUB MILHH  NUMPEOPLE  \
# 0   '11000002'         -6    '-6'   '-6'      '-6'     '8'  '-6'         -6
# 1   '11000003'        199    '-6'    '2'      '-6'     '8'   '6'          3
# 2   '11000005'        501    '-6'   '-6'      '-6'    '-6'   '4'          2
# 3   '11000006'        232    '-6'   '-6'      '-6'    '-6'   '6'          3
# 4   '11000008'        231    '-6'    '1'      '-6'     '8'   '6'          1
# 5   '11000009'         -6    '-6'   '-6'      '-6'    '-6'  '-6'         -6
# 6   '11000010'        202    '-6'    '2'      '-6'     '1'   '6'          1
# 7   '11000013'        501    '-6'   '-6'      '-6'    '-6'   '4'          3
# 8   '11000015'        501    '-6'   '-6'      '-6'     '8'   '6'          2
# 9   '11000016'        501    '-6'   '-6'      '-6'    '-6'   '6'          3
# 10  '11000019'        348    '-6'   '-6'      '-6'     '1'   '6'          1
# ...

# %%
ag = df[df["HINCP"] <= 0]

ag.describe()
# Out:
#          PERPOVLVL    NUMPEOPLE        HINCP
# count  8115.000000  8115.000000  8115.000000
# mean     -5.160690    -5.063586    -5.896734
# std       2.274064     2.572325    55.479781
# min      -6.000000    -6.000000 -5000.000000
# 25%      -6.000000    -6.000000    -6.000000
# 50%      -6.000000    -6.000000    -6.000000
# 75%      -6.000000    -6.000000    -6.000000
# max       1.000000     9.000000     0.000000

# %% [markdown]
# ### Cleaning - household.csv

# %%
# Remove single quotes and convert to int, except CONTROL column
for col in df.columns:
    if col != "CONTROL":
        df[col] = df[col].astype(str).str.replace("'", "").astype(int)

# Drop rows where HINCP is below 0
df = df[df["HINCP"] >= 0]

print(f"Rows after cleaning: {len(df)}")
df
# Out:
# Rows after cleaning: 48526
#           CONTROL  PERPOVLVL  HINFORC  HIHALF  RENTCNTRL  RENTSUB  MILHH  \
# 1      '11000003'        199       -6       2         -6        8      6
# 2      '11000005'        501       -6      -6         -6       -6      4
# 3      '11000006'        232       -6      -6         -6       -6      6
# 4      '11000008'        231       -6       1         -6        8      6
# 6      '11000010'        202       -6       2         -6        1      6
# ...           ...        ...      ...     ...        ...      ...    ...
# 55661  '11100189'        100       -6      -6         -6       -6      6
# 55662  '11100190'        501       -6      -6         -6       -6      6
# 55663  '11100193'        501       -6       2         -6        8      4
# 55664  '11100196'        187       -6       1         -6        8      6
# 55668  '11100208'        202       -6      -6         -6       -6      6
#
# ...

# %% [markdown]
# ### Feature Engineering - household.csv

# %%
# Create 'at risk' column based on conditions
df["at_risk"] = (
    (df["PERPOVLVL"] <= 100)
    | (df["HIHALF"] == 1)
    | (df["HIMORTFORC"] == 1)
    | (df["HIEVICNOTE"] == 1)
    | (df["HIBEHINDFRQ"].isin([2, 3, 4]))
    | (df["HINFORC"] == 1)
).astype(int)

# Drop columns used to make 'at risk' column
df = df.drop(
    columns=[
        "PERPOVLVL",
        "HIHALF",
        "HIBEHINDFRQ",
        "HIEVICNOTE",
        "HIMORTFORC",
        "HINFORC",
    ]
)

df
# Out:
#           CONTROL  RENTCNTRL  RENTSUB  MILHH  NUMPEOPLE  FS  DISHH  HUDSUB  \
# 1      '11000003'         -6        8      6          3   2      1       3
# 2      '11000005'         -6       -6      4          2  -6      1      -6
# 3      '11000006'         -6       -6      6          3   2      2      -6
# 4      '11000008'         -6        8      6          1  -6      1       3
# 6      '11000010'         -6        1      6          1   2      1       1
# ...           ...        ...      ...    ...        ...  ..    ...     ...
# 55661  '11100189'         -6       -6      6          1   2      2      -6
# 55662  '11100190'         -6       -6      6          4  -6      2      -6
# 55663  '11100193'         -6        8      4          3   2      2       3
# 55664  '11100196'         -6        8      6          1   2      2       3
# 55668  '11100208'         -6       -6      6          6   2     -9      -6
#
#         HINCP  at_risk
# 1       48000        0
# ...

# %%
df["at_risk"].value_counts()
# Out:
# at_risk
# 0    37883
# 1    10643
# Name: count, dtype: int64

# %%
df.to_csv("../data/household_cleaned-v2.csv", index=False)

df
# Out:
#           CONTROL  RENTCNTRL  RENTSUB  MILHH  NUMPEOPLE  FS  DISHH  HUDSUB  \
# 1      '11000003'         -6        8      6          3   2      1       3
# 2      '11000005'         -6       -6      4          2  -6      1      -6
# 3      '11000006'         -6       -6      6          3   2      2      -6
# 4      '11000008'         -6        8      6          1  -6      1       3
# 6      '11000010'         -6        1      6          1   2      1       1
# ...           ...        ...      ...    ...        ...  ..    ...     ...
# 55661  '11100189'         -6       -6      6          1   2      2      -6
# 55662  '11100190'         -6       -6      6          4  -6      2      -6
# 55663  '11100193'         -6        8      4          3   2      2       3
# 55664  '11100196'         -6        8      6          1   2      2       3
# 55668  '11100208'         -6       -6      6          6   2     -9      -6
#
#         HINCP  at_risk
# 1       48000        0
# ...

# %%
(df["MILHH"].isin([6, -6])).astype(int).value_counts()
# Out:
# MILHH
# 1    42547
# 0     5979
# Name: count, dtype: int64

# %% [markdown]
# # Person CSV Cleaning & Feature Engineering
#
# ### Features being targeted
#
# As mentioned above, the features to work with in the `person.csv` dataset to mirror the form submission are as follows:
#
# **Persons age**
#
#     AGE
#
# **Public Assistance Income**
#
#     PAP
#
# ---
#
# ### Features being used to determine at risk profiles:
#
# **Veteran Status**
#
# Since MILHH is to be used to cover the question regarding the entire household and whether there are veterans living in the household, MIL can be used as a signal to signify some level of 'at risk' and then dropped
#
#     MIL
#     1: Now on active duty
#     2: Served on active duty in the past
#     3: Never served in military
#     M or -9: Not reported
#     N or -6: Not applicable
#
# After first experiment with above knowledge, consider using PHEAR/PSEE/PMEMRY/PWALK/PCARE to consider more 'at risk' profiles using feature corresponding to disabilities
#
# (https://www.census.gov/data-tools/demo/codebook/ahs/ahsdict.html?s_keyword=&s_year=2023%20National,2023%20Metro&s_topic=&s_availability=PUF&s_variablelist=PCARE,PHEAR,PMEMRY,PWALK,PSEE)
#
# ### Consider adding to the form
#
# **SOGIRLGBTP** - Respondent LGBT Status (will reduce person.csv to size of household.csv bc it is just the respondent and not taking into account everyone in the household)
#
# (https://www.census.gov/data-tools/demo/codebook/ahs/ahsdict.html?s_keyword=&s_year=2023%20National,2023%20Metro&s_topic=&s_availability=PUF&s_variablelist=SOGIRLGBTP)
#
# **GRAD** - Level of Education
#
# (https://www.census.gov/data-tools/demo/codebook/ahs/ahsdict.html?s_keyword=&s_year=2023%20National,2023%20Metro&s_topic=&s_availability=PUF&s_variablelist=GRAD)
#
# **SEX** - Sex of Person
#
# (https://www.census.gov/data-tools/demo/codebook/ahs/ahsdict.html?s_keyword=&s_year=2023%20National,2023%20Metro&s_topic=&s_availability=PUF&s_variablelist=SEX)

# %%
df2 = pd.read_csv(
    filepath_or_buffer="../data/person.csv", usecols=["CONTROL", "AGE", "PAP", "MIL"]
)

df2["MIL"] = df2["MIL"].str.replace("'", "").astype(int)

df2
# Out:
#            CONTROL  AGE  MIL  PAP
# 0       '11000003'   21    3    0
# 1       '11000003'   21    3    0
# 2       '11000003'    1   -6   -6
# 3       '11000005'   76    2    0
# 4       '11000005'   75    2    0
# ...            ...  ...  ...  ...
# 114471  '11100208'   45    3    0
# 114472  '11100208'   45    3   -6
# 114473  '11100208'   18    3   -6
# 114474  '11100208'   17   -9   -6
# 114475  '11100208'   14   -6   -6
#
# [114476 rows x 4 columns]

# %%
df2["PAP"].value_counts()
# Out:
# PAP
#  0        87118
# -6        25509
#  2400        75
#  280         71
#  200         60
#           ...
#  13000        1
#  8300         1
#  730          1
#  760          1
#  910          1
# Name: count, Length: 192, dtype: int64

# %%
df2.to_csv("../data/person_cleaned-v2.csv", index=False)

# %% [markdown]
# # Person & Household CSVs Merged
#
# This will become our training and testing dataset by merging all household features to each person it's associated with by using the CONTROL column.
#
# The **MIL** column will now be used to add more 'at risk' profiles that can be allocated to specific people since **MILHH** is asked in a more generalized way. However, **MILHH** will be used to cover the question about Veteran status in the form since it is also asked in a non-specific way.
#
# Another possible question to ask is one that can differentiate between different conflict eras as the dataset also provides insight into that. In the following link, it says those who served in Vietnam are at hte greatest risk
#
# (https://moneyzine.com/personal-finance/homelessness-statistics/)

# %%
main_df = pd.merge(df2, df, on="CONTROL", how="inner", validate="many_to_one")

main_df
# Out:
#            CONTROL  AGE  MIL  PAP  RENTCNTRL  RENTSUB  MILHH  NUMPEOPLE  FS  \
# 0       '11000003'   21    3    0         -6        8      6          3   2
# 1       '11000003'   21    3    0         -6        8      6          3   2
# 2       '11000003'    1   -6   -6         -6        8      6          3   2
# 3       '11000005'   76    2    0         -6       -6      4          2  -6
# 4       '11000005'   75    2    0         -6       -6      4          2  -6
# ...            ...  ...  ...  ...        ...      ...    ...        ...  ..
# 114468  '11100208'   45    3    0         -6       -6      6          6   2
# 114469  '11100208'   45    3   -6         -6       -6      6          6   2
# 114470  '11100208'   18    3   -6         -6       -6      6          6   2
# 114471  '11100208'   17   -9   -6         -6       -6      6          6   2
# 114472  '11100208'   14   -6   -6         -6       -6      6          6   2
#
#         DISHH  HUDSUB   HINCP  at_risk
# ...

# %%
print("Null values in main_df:\n")
print(main_df.isna().sum())
print("\n\n")

print("Data types in main_df:\n")
print(main_df.dtypes)
# Out:
# Null values in main_df:
#
# CONTROL      0
# AGE          0
# MIL          0
# PAP          0
# RENTCNTRL    0
# RENTSUB      0
# MILHH        0
# NUMPEOPLE    0
# FS           0
# DISHH        0
# HUDSUB       0
# HINCP        0
# at_risk      0
# dtype: int64
#
#
#
# Data types in main_df:
#
# CONTROL      object
# AGE           int64
# MIL           int64
# PAP           int64
# RENTCNTRL     int64
# RENTSUB       int64
# MILHH         int64
# NUMPEOPLE     int64
# FS            int64
# DISHH         int64
# HUDSUB        int64
# HINCP         int64
# at_risk       int64
# dtype: object

# %% [markdown]
# # Final Feature Engineering before Training

# %%
# About a 4:1 class ratio of 0s to 1s
main_df["at_risk"].value_counts()
# Out:
# at_risk
# 0    92523
# 1    21950
# Name: count, dtype: int64

# %%
main_df
# Out:
#            CONTROL  AGE  MIL  PAP  RENTCNTRL  RENTSUB  MILHH  NUMPEOPLE  FS  \
# 0       '11000003'   21    3    0         -6        8      6          3   2
# 1       '11000003'   21    3    0         -6        8      6          3   2
# 2       '11000003'    1   -6   -6         -6        8      6          3   2
# 3       '11000005'   76    2    0         -6       -6      4          2  -6
# 4       '11000005'   75    2    0         -6       -6      4          2  -6
# ...            ...  ...  ...  ...        ...      ...    ...        ...  ..
# 114468  '11100208'   45    3    0         -6       -6      6          6   2
# 114469  '11100208'   45    3   -6         -6       -6      6          6   2
# 114470  '11100208'   18    3   -6         -6       -6      6          6   2
# 114471  '11100208'   17   -9   -6         -6       -6      6          6   2
# 114472  '11100208'   14   -6   -6         -6       -6      6          6   2
#
#         DISHH  HUDSUB   HINCP  at_risk
# ...

# %%
(main_df["FS"] == 1).value_counts()  # 1 = food stamp recipient, 2 = not a recipient
# Out:
# FS
# False    99398
# True     15075
# Name: count, dtype: int64

# %%
(main_df["PAP"] > 0).value_counts()  # 0 = not a PAP, 1 = PAP
# Out:
# PAP
# False    112624
# True       1849
# Name: count, dtype: int64

# %%
(main_df["HUDSUB"] == 1).value_counts()  # 1 = HUD recipient, 2 = not a recipient
# Out:
# HUDSUB
# False    108336
# True       6137
# Name: count, dtype: int64

# %%
(main_df["RENTSUB"].isin([1, 2, 3, 4, 5])).value_counts()  # 1 = rent subsidy, 2 = not a
# Out:
# RENTSUB
# False    100604
# True      13869
# Name: count, dtype: int64

# %%
(main_df["RENTCNTRL"] == 1).value_counts()
# Out:
# RENTCNTRL
# False    113423
# True       1050
# Name: count, dtype: int64

# %%
(
    (main_df["RENTSUB"].isin([1, 2, 3, 4, 5]))
    | (main_df["FS"] == 1)
    | (main_df["PAP"] > 0)
    | (main_df["HUDSUB"] == 1)
    | (main_df["RENTCNTRL"] == 1)
).value_counts()  # 1 =
# Out:
# False    91566
# True     22907
# Name: count, dtype: int64

# %%
# Create new column gov_assistance (0 or 1) with FS = 1 or PAP > 0
main_df["gov_assistance"] = (
    (main_df["RENTSUB"].isin([1, 2, 3, 4, 5]))
    | (main_df["FS"] == 1)
    | (main_df["PAP"] > 0)
    | (main_df["HUDSUB"] == 1)
    | (main_df["RENTCNTRL"] == 1)
).astype(int)

main_df = main_df.drop(columns=["FS", "PAP", "HUDSUB", "RENTSUB", "RENTCNTRL"])

main_df["gov_assistance"].value_counts()
# Out:
# gov_assistance
# 0    91566
# 1    22907
# Name: count, dtype: int64

# %%
main_df
# Out:
#            CONTROL  AGE  MIL  MILHH  NUMPEOPLE  DISHH   HINCP  at_risk  \
# 0       '11000003'   21    3      6          3      1   48000        0
# 1       '11000003'   21    3      6          3      1   48000        0
# 2       '11000003'    1   -6      6          3      1   48000        0
# 3       '11000005'   76    2      4          2      1  292500        0
# 4       '11000005'   75    2      4          2      1  292500        0
# ...            ...  ...  ...    ...        ...    ...     ...      ...
# 114468  '11100208'   45    3      6          6     -9   86050        0
# 114469  '11100208'   45    3      6          6     -9   86050        0
# 114470  '11100208'   18    3      6          6     -9   86050        0
# 114471  '11100208'   17   -9      6          6     -9   86050        0
# 114472  '11100208'   14   -6      6          6     -9   86050        0
#
#         gov_assistance
# 0                    0
# 1                    0
# 2                    0
# ...

# %%
# Drop all rows with -9 in any column
main_df = main_df[~main_df.isin([-9]).any(axis=1)]

# Drop MIL column bc form question isn't specific enough to cover it and CONTROL now that datasets are merged
main_df = main_df.drop(columns=["MIL", "CONTROL"])

main_df.to_csv("../data/main_df-v2.csv", index=False)

main_df
# Out:
#         AGE  MILHH  NUMPEOPLE  DISHH   HINCP  at_risk  gov_assistance
# 0        21      6          3      1   48000        0               0
# 1        21      6          3      1   48000        0               0
# 2         1      6          3      1   48000        0               0
# 3        76      4          2      1  292500        0               0
# 4        75      4          2      1  292500        0               0
# ...     ...    ...        ...    ...     ...      ...             ...
# 114462    2      6          4      2  194000        0               0
# 114463   49      4          3      2  125000        0               0
# 114464   21      4          3      2  125000        0               0
# 114465   22      4          3      2  125000        0               0
# 114466   73      6          1      2   27000        1               0
#
# [111507 rows x 7 columns]

# %%
print("Number of unique values in each column:\n")
print(main_df.nunique())
print("\n\n")

print("Value counts for columns with less than 10 unique values:\n")
cols = ["MILHH", "NUMPEOPLE", "DISHH", "gov_assistance", "at_risk"]

for col in cols:
    print(main_df.value_counts(subset=[col]))
    print("\n")
# Out:
# Number of unique values in each column:
#
# AGE                 82
# MILHH                6
# NUMPEOPLE           14
# DISHH                2
# HINCP             6776
# at_risk              2
# gov_assistance       2
# dtype: int64
#
#
#
# Value counts for columns with less than 10 unique values:
#
# MILHH
# 6        98037
# 2        11282
# 1         1224
# 4          770
# 5          143
# 3           51
# Name: count, dtype: int64
#
#
# NUMPEOPLE
# 2            30608
# 4            22626
# 3            19525
# 1            15747
# 5            12974
# 6             5680
# 7             2399
# 8             1070
# 9              454
# 10             190
# 12             106
# 11              75
# 13              38
# 15              15
# Name: count, dtype: int64
#
#
# DISHH
# 2        85493
# 1        26014
# Name: count, dtype: int64
#
#
# gov_assistance
# 0                 88975
# 1                 22532
# Name: count, dtype: int64
#
#
# at_risk
# 0          90059
# ...

# %% [markdown]
# ## Turn DISHH & MILHH to binary values

# %%
main_df["MILHH"] = (main_df["MILHH"].isin([1, 2, 3, 4, 5])).astype(int)

# %%
main_df["DISHH"] = (main_df["DISHH"] == 1).astype(int)

# %%
main_df["MILHH"].value_counts()  # 1 = military household, 0 = not a military household
# Out:
# MILHH
# 0    98037
# 1    13470
# Name: count, dtype: int64

# %%
main_df
# Out:
#         AGE  MILHH  NUMPEOPLE  DISHH   HINCP  at_risk  gov_assistance
# 0        21      0          3      1   48000        0               0
# 1        21      0          3      1   48000        0               0
# 2         1      0          3      1   48000        0               0
# 3        76      1          2      1  292500        0               0
# 4        75      1          2      1  292500        0               0
# ...     ...    ...        ...    ...     ...      ...             ...
# 114462    2      0          4      0  194000        0               0
# 114463   49      1          3      0  125000        0               0
# 114464   21      1          3      0  125000        0               0
# 114465   22      1          3      0  125000        0               0
# 114466   73      0          1      0   27000        1               0
#
# [111507 rows x 7 columns]

# %%
main_df.to_csv("../data/final_df-v2.csv", index=False)

# %% [markdown]
# # Scaling, Training, and Testing

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.metrics import (
    confusion_matrix, classification_report, roc_curve,
    roc_auc_score, precision_recall_curve, average_precision_score
)
import shap
from sklearn.inspection import permutation_importance
import seaborn as sns
import matplotlib.pyplot as plt

final = pd.read_csv('../data/final_df-v2.csv')

x = final.drop(columns=['at_risk'] )
y = final['at_risk']

continuous_cols = [ 'HINCP', 'AGE', 'NUMPEOPLE']
cat_cols = [col for col in x.columns if col not in continuous_cols]
cat_idx = [x.columns.get_loc(col) for col in cat_cols]

print(f"Categorical columns: {cat_cols}\n Cat Index: {cat_idx}")

preprocessor = ColumnTransformer([('num', RobustScaler(), continuous_cols)], remainder='passthrough')

model_pipeline = Pipeline(
    [
        ("preprocessor", preprocessor),
        (
            "classifier",
            XGBClassifier(
                n_estimators=100,
                learning_rate=0.1,
                scale_pos_weight=1.5,
                random_state=42,
                objective="binary:logistic",
                eval_metric=["logloss", "auc"],
            ),
        ),
    ]
)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

model = model_pipeline.fit(x_train, y_train)

y_pred = model.predict(x_test)
y_pred_proba = model.predict_proba(x_test)[:, 1]
y_pred_custom = (y_pred_proba > 0.4).astype(int)

print("\nClassification Report:")
print(classification_report(y_test, y_pred_custom))

# Confusion Matrix & Plotting
sns.set_style("whitegrid")

conf_matrix = confusion_matrix(y_test, y_pred_custom)
plt.figure(figsize=(8, 6))
sns.heatmap(
    conf_matrix,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["Not at risk", "At risk"],
    yticklabels=["Not at risk", "At risk"],
)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - 40% Threshold")
plt.show()
plt.close()
# Out:
# Categorical columns: ['MILHH', 'DISHH', 'gov_assistance']
#  Cat Index: [1, 3, 5]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97     18012
#            1       0.98      0.80      0.88      4290
#
#     accuracy                           0.96     22302
#    macro avg       0.97      0.90      0.93     22302
# weighted avg       0.96      0.96      0.96     22302

# %% [markdown]
# # ROC & AUC Curve

# %%
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
auc = roc_auc_score(y_test, y_pred_proba)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f"AUC = {auc:.4f}")
plt.plot([0, 1], [0, 1], "k--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()
plt.close()

# %% [markdown]
# # Precision Recall Curve

# %%
precision_curve, recall_curve, _ = precision_recall_curve(y_test, y_pred_proba)
ap = average_precision_score(y_test, y_pred_proba)

plt.figure(figsize=(8, 6))
plt.plot(recall_curve, precision_curve, label=f"AP = {ap:.4f}")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend()
plt.show()
plt.close()

# %% [markdown]
# # Cross-validation
#
# Double check model performance on multiple train/test splits.

# %%
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
cv_accuracy = cross_val_score(model, x, y, cv=cv, scoring="accuracy")
cv_precision = cross_val_score(model, x, y, cv=cv, scoring="precision")
cv_recall = cross_val_score(model, x, y, cv=cv, scoring="recall")
cv_f1 = cross_val_score(model, x, y, cv=cv, scoring="f1")
cv_roc_auc = cross_val_score(model, x, y, cv=cv, scoring="roc_auc")

print("\nCross-validation Results:")
print(f"CV Accuracy: {cv_accuracy.mean():.4f} ± {cv_accuracy.std():.4f}")
print(f"CV Precision: {cv_precision.mean():.4f} ± {cv_precision.std():.4f}")
print(f"CV Recall: {cv_recall.mean():.4f} ± {cv_recall.std():.4f}")
print(f"CV F1-score: {cv_f1.mean():.4f} ± {cv_f1.std():.4f}")
print(f"CV ROC AUC: {cv_roc_auc.mean():.4f} ± {cv_roc_auc.std():.4f}")
# Out:
# Cross-validation Results:
# CV Accuracy: 0.9594 ± 0.0014
# CV Precision: 0.9858 ± 0.0010
# CV Recall: 0.8003 ± 0.0070
# CV F1-score: 0.8834 ± 0.0044
# CV ROC AUC: 0.9523 ± 0.0019

# %% [markdown]
# # Permutation Importance

# %%
# Needed to use log scale for better visualization of small values
plt.figure(figsize=(12, 8))

result = permutation_importance(
    model,
    x_test,
    y_test,
    n_repeats=500,  # Increase for more stable results
    random_state=42,
)

# df for easier manipulation
importance_df = pd.DataFrame(
    {
        "Feature": x.columns,
        "Importance": result.importances_mean,
        "Std": result.importances_std,
    }
)

# add small epsilon to zero values for log scale
importance_df["Importance"] = importance_df["Importance"] + 1e-10  # Prevent log(0)

# Create horizontal bar chart with log scale
sns.barplot(
    x="Importance",
    y="Feature",
    data=importance_df.sort_values(by="Importance", ascending=False),
    palette="viridis",
)

plt.xscale("log")  # Use logarithmic scale for x-axis
plt.title("Top Feature Importance (Log Scale)", fontsize=16)
plt.xlabel("Mean Decrease in Model Performance (log scale)", fontsize=14)
plt.ylabel("")
plt.tight_layout()
plt.grid(axis="x", linestyle="--", alpha=0.7)
plt.show()
plt.close()
# Out:
# C:\Users\Bryan\AppData\Local\Temp\ipykernel_21232\4278148563.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# # SHAP

# %%
import shap

# use the xgboost-specific shap explainer for better performance
xgb_model = model.named_steps["classifier"]

# Transform test data through preprocessing first
x_test_processed = model.named_steps["preprocessor"].transform(x_test)

# Create explainer
explainer = shap.TreeExplainer(xgb_model)

# Calculate SHAP values
shap_values = explainer.shap_values(x_test_processed)

# Summary plot
plt.figure(figsize=(30, 18))
shap.summary_plot(
    shap_values,
    x_test_processed,
    feature_names=model.named_steps["preprocessor"].get_feature_names_out(),
)

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

# Train a surrogate decision tree on your model's predictions
surrogate_model = DecisionTreeClassifier(max_depth=4)
surrogate_model.fit(x_test, model.predict(x_test))

# Plot the tree
plt.figure(figsize=(60, 20))
plot_tree(
    surrogate_model,
    feature_names=x.columns,
    class_names=["Not at risk", "At risk"],
    filled=True,
    rounded=True,
    fontsize=22,
)
plt.title("Surrogate Decision Tree for Housing Risk Model", fontsize=50)
plt.tight_layout()
plt.show()

# Calculate fidelity (how well the surrogate matches the original model)
surrogate_preds = surrogate_model.predict(x_test)
original_preds = model.predict(x_test)
fidelity = np.mean(surrogate_preds == original_preds)
print(f"Surrogate model fidelity: {fidelity:.4f}")
# Out:
# Surrogate model fidelity: 0.9859
